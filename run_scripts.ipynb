# %%
# !python3 main.py \
    --chromedriver=/home/ptdat/.wdm/drivers/chromedriver/linux64/130.0.6723.58/chromedriver-linux64/chromedriver \
    --crawler=page_crawler \
    --user=user1 \
    --crawler-dir=./data/ \
    --sleep-weibull-lambda=7 \
    --max-loading-wait=90 \
    --cookies-dir=./cookies/ \
    --secrets-json=./secrets.json \
    # --headless \
    --error-screenshot-dir=./error-screenshots/ \
    --max-error-trials=5
# Out:
# [Page Crawler][INFO][20-10 18:01:02]: Initializing...
# [Page Crawler][INFO][20-10 18:01:04]: Driver started
# [Page Crawler][INFO][20-10 18:01:04]: Ensuring user logging in
# [Page Crawler][INFO][20-10 18:01:04]: Found user's credentials cached as cookies
# [Page Crawler][INFO][20-10 18:01:09]: Saved/Refreshed cookies
# [Page Crawler][INFO][20-10 18:01:09]: Matched as URL for navigation: https://www.facebook.com/UnderArmourVietnam
# [Page Crawler][INFO][20-10 18:01:16]: Enqueuing 0 new navigation URLs
# [Page Crawler][INFO][20-10 18:01:16]: Selectively enqueuing 0 new parsing URLs
# [Page Crawler][INFO][20-10 18:01:16]: Matched as URL for parsing: https://www.facebook.com/UnderArmourVietnam
# [Page Crawler][INFO][20-10 18:01:19]: Opened new tab to https://www.facebook.com/UnderArmourVietnam
# RAM Usage (GB):  53%|████████████▏          | 8.1/15.33 [00:01<00:01,  6.22it/s]
# [Page Crawler][ERROR][20-10 18:01:20]: Restore https://www.facebook.com/UnderArmourVietnam to queue due to error:
# StaleElementReferenceException: Message: stale element reference: stale element not found in the current frame
#   (Session info: chrome=130.0.6723.58)
# Stacktrace:
# #0 0x63beb312c0aa <unknown>
# #1 0x63beb2c431a0 <unknown>
# #2 0x63beb2c48ef3 <unknown>
# #3 0x63beb2c4aba5 <unknown>
# #4 0x63beb2c4ac2c <unknown>
# #5 0x63beb2c95dfe <unknown>
# #6 0x63beb2c95226 <unknown>
# #7 0x63beb2cdb34a <unknown>
# #8 0x63beb2cb3d82 <unknown>
# #9 0x63beb2cd2866 <unknown>
# #10 0x63beb2cb3b23 <unknown>
# #11 0x63beb2c82990 <unknown>
# #12 0x63beb2c8396e <unknown>
# #13 0x63beb30f816b <unknown>
# #14 0x63beb30fbf68 <unknown>
# #15 0x63beb30e564c <unknown>
# #16 0x63beb30fcae7 <unknown>
# #17 0x63beb30ca4af <unknown>
# #18 0x63beb311a4f8 <unknown>
# #19 0x63beb311a6c0 <unknown>
# #20 0x63beb312af26 <unknown>
# #21 0x72349689ca94 <unknown>
# #22 0x723496929c3c <unknown>
#
# Traceback (most recent call last):
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/base_crawler.py", line 219, in start
#     self._handle_parse_url(url)
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/base_crawler.py", line 271, in _handle_parse_url
#     data = self.parse()
#            ^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/page_crawler/crawler.py", line 137, in parse
#     self.post_collect_criteria.update_progress(self.chrome)
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/page_crawler/crawler.py", line 71, in update_progress
#     ActionChains(driver).move_to_element(last_post_datetime_a).perform()
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/common/action_chains.py", line 75, in perform
#     self.w3c_actions.perform()
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/common/actions/action_builder.py", line 77, in perform
#     self.driver.execute(Command.W3C_ACTIONS, enc)
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 424, in execute
#     self.error_handler.check_response(response)
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: stale element reference: stale element not found in the current frame
#   (Session info: chrome=130.0.6723.58)
# Stacktrace:
# #0 0x63beb312c0aa <unknown>
# #1 0x63beb2c431a0 <unknown>
# #2 0x63beb2c48ef3 <unknown>
# #3 0x63beb2c4aba5 <unknown>
# #4 0x63beb2c4ac2c <unknown>
# #5 0x63beb2c95dfe <unknown>
# #6 0x63beb2c95226 <unknown>
# #7 0x63beb2cdb34a <unknown>
# #8 0x63beb2cb3d82 <unknown>
# #9 0x63beb2cd2866 <unknown>
# #10 0x63beb2cb3b23 <unknown>
# #11 0x63beb2c82990 <unknown>
# #12 0x63beb2c8396e <unknown>
# #13 0x63beb30f816b <unknown>
# #14 0x63beb30fbf68 <unknown>
# #15 0x63beb30e564c <unknown>
# #16 0x63beb30fcae7 <unknown>
# #17 0x63beb30ca4af <unknown>
# #18 0x63beb311a4f8 <unknown>
# #19 0x63beb311a6c0 <unknown>
# #20 0x63beb312af26 <unknown>
# #21 0x72349689ca94 <unknown>
# #22 0x723496929c3c <unknown>
#
#
# [Page Crawler][WARNING][20-10 18:01:20]: Attempting 1st retrial...
# [Page Crawler][INFO][20-10 18:01:27]: Matched as URL for navigation: https://www.facebook.com/UnderArmourVietnam
# [Page Crawler][INFO][20-10 18:01:32]: Enqueuing 0 new navigation URLs
# [Page Crawler][INFO][20-10 18:01:32]: Selectively enqueuing 0 new parsing URLs
# [Page Crawler][INFO][20-10 18:01:32]: Matched as URL for parsing: https://www.facebook.com/UnderArmourVietnam
# [Page Crawler][INFO][20-10 18:01:34]: Opened new tab to https://www.facebook.com/UnderArmourVietnam
# RAM Usage (GB):  53%|████████████▎          | 8.2/15.33 [00:01<00:00,  7.32it/s]
# [Page Crawler][ERROR][20-10 18:01:35]: Restore https://www.facebook.com/UnderArmourVietnam to queue due to error:
# JavascriptException: Message: javascript error: {"status":60,"value":"https://www.facebook.com/UnderArmourVietnam?__cft__[0]=AZWIzxCqsk46sUjAluqVvUvuDB-1c9edKXG-JWpeCY508H1qNlG2OLhFmPBhNxsWdz3ts00-3qyT6e2PB4xtQnuR4i5EQUFa5t3ycfeXRnHPa5wipk_ILng9hZXaSKvUYr69PxuXWaoBx5ODMBdFDGZuHrpHmmbkv0alTynnXmQjqpr9oGhxGMlWAaQE6Cvrb2E&__tn__=%2CO%2CP-R#?bgi has no size and location"}
#   (Session info: chrome=130.0.6723.58)
# Stacktrace:
# #0 0x63beb312c0aa <unknown>
# #1 0x63beb2c431a0 <unknown>
# #2 0x63beb2c48ef3 <unknown>
# #3 0x63beb2c4aba5 <unknown>
# #4 0x63beb2c4ac2c <unknown>
# #5 0x63beb2c95dfe <unknown>
# #6 0x63beb2c95226 <unknown>
# #7 0x63beb2cdb34a <unknown>
# #8 0x63beb2cb3d82 <unknown>
# #9 0x63beb2cd2866 <unknown>
# #10 0x63beb2cb3b23 <unknown>
# #11 0x63beb2c82990 <unknown>
# #12 0x63beb2c8396e <unknown>
# #13 0x63beb30f816b <unknown>
# #14 0x63beb30fbf68 <unknown>
# #15 0x63beb30e564c <unknown>
# #16 0x63beb30fcae7 <unknown>
# #17 0x63beb30ca4af <unknown>
# #18 0x63beb311a4f8 <unknown>
# #19 0x63beb311a6c0 <unknown>
# #20 0x63beb312af26 <unknown>
# #21 0x72349689ca94 <unknown>
# #22 0x723496929c3c <unknown>
#
# Traceback (most recent call last):
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/base_crawler.py", line 219, in start
#     self._handle_parse_url(url)
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/base_crawler.py", line 271, in _handle_parse_url
#     data = self.parse()
#            ^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/page_crawler/crawler.py", line 137, in parse
#     self.post_collect_criteria.update_progress(self.chrome)
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/page_crawler/crawler.py", line 71, in update_progress
#     ActionChains(driver).move_to_element(last_post_datetime_a).perform()
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/common/action_chains.py", line 75, in perform
#     self.w3c_actions.perform()
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/common/actions/action_builder.py", line 77, in perform
#     self.driver.execute(Command.W3C_ACTIONS, enc)
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 424, in execute
#     self.error_handler.check_response(response)
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.JavascriptException: Message: javascript error: {"status":60,"value":"https://www.facebook.com/UnderArmourVietnam?__cft__[0]=AZWIzxCqsk46sUjAluqVvUvuDB-1c9edKXG-JWpeCY508H1qNlG2OLhFmPBhNxsWdz3ts00-3qyT6e2PB4xtQnuR4i5EQUFa5t3ycfeXRnHPa5wipk_ILng9hZXaSKvUYr69PxuXWaoBx5ODMBdFDGZuHrpHmmbkv0alTynnXmQjqpr9oGhxGMlWAaQE6Cvrb2E&__tn__=%2CO%2CP-R#?bgi has no size and location"}
#   (Session info: chrome=130.0.6723.58)
# Stacktrace:
# #0 0x63beb312c0aa <unknown>
# #1 0x63beb2c431a0 <unknown>
# #2 0x63beb2c48ef3 <unknown>
# #3 0x63beb2c4aba5 <unknown>
# #4 0x63beb2c4ac2c <unknown>
# #5 0x63beb2c95dfe <unknown>
# #6 0x63beb2c95226 <unknown>
# #7 0x63beb2cdb34a <unknown>
# #8 0x63beb2cb3d82 <unknown>
# #9 0x63beb2cd2866 <unknown>
# #10 0x63beb2cb3b23 <unknown>
# #11 0x63beb2c82990 <unknown>
# #12 0x63beb2c8396e <unknown>
# #13 0x63beb30f816b <unknown>
# #14 0x63beb30fbf68 <unknown>
# #15 0x63beb30e564c <unknown>
# #16 0x63beb30fcae7 <unknown>
# #17 0x63beb30ca4af <unknown>
# #18 0x63beb311a4f8 <unknown>
# #19 0x63beb311a6c0 <unknown>
# #20 0x63beb312af26 <unknown>
# #21 0x72349689ca94 <unknown>
# #22 0x723496929c3c <unknown>
#
#
# [Page Crawler][WARNING][20-10 18:01:35]: Attempting 2nd retrial...
# [Page Crawler][INFO][20-10 18:01:43]: Matched as URL for navigation: https://www.facebook.com/UnderArmourVietnam
# [Page Crawler][INFO][20-10 18:01:45]: Enqueuing 0 new navigation URLs
# [Page Crawler][INFO][20-10 18:01:45]: Selectively enqueuing 0 new parsing URLs
# [Page Crawler][INFO][20-10 18:01:45]: Matched as URL for parsing: https://www.facebook.com/UnderArmourVietnam
# [Page Crawler][INFO][20-10 18:01:49]: Opened new tab to https://www.facebook.com/UnderArmourVietnam
# RAM Usage (GB):  54%|█ | 8.26/15.33 [01:11<01:01,  8.67s/it, # Loaded posts: 25]
# [Page Crawler][INFO][20-10 18:03:00]: Post collect stopping criteria has met with threshold of 2024-09-01 00:00:00
# [Page Crawler][INFO][20-10 18:03:01]: Located 27 posts
# Parsing posts:   0%|                                     | 0/27 [00:01<?, ?it/s]
# [Page Crawler][ERROR][20-10 18:03:02]: Restore https://www.facebook.com/UnderArmourVietnam to queue due to error:
# InvalidSelectorException: Message: invalid selector
# from javascript error: {"status":32,"value":"Unable to locate an element with the xpath expression (((//div[@class='x9f619 x1n2onr6 x1ja2u2z xeuugli xs83m0k xjl7jj x1xmf6yo x1emribx x1e56ztr x1i64zmx x19h7ccj xu9j1y6 x7ep2pv']/div)[last()]/div/div[@class='x1yztbdb x1n2onr6 xh8yej3 x1ja2u2z'])[1]//h2/../../../../div//a because of the following error:\nSyntaxError: Failed to execute 'evaluate' on 'Document': The string '(((//div[@class='x9f619 x1n2onr6 x1ja2u2z xeuugli xs83m0k xjl7jj x1xmf6yo x1emribx x1e56ztr x1i64zmx x19h7ccj xu9j1y6 x7ep2pv']/div)[last()]/div/div[@class='x1yztbdb x1n2onr6 xh8yej3 x1ja2u2z'])[1]//h2/../../../../div//a' is not a valid XPath expression."}
#   (Session info: chrome=130.0.6723.58)
# Stacktrace:
# #0 0x63beb312c0aa <unknown>
# #1 0x63beb2c431a0 <unknown>
# #2 0x63beb2c48ef3 <unknown>
# #3 0x63beb2c4aba5 <unknown>
# #4 0x63beb2c4ac2c <unknown>
# #5 0x63beb2c8f965 <unknown>
# #6 0x63beb2c8ffa1 <unknown>
# #7 0x63beb2c84b53 <unknown>
# #8 0x63beb2cb3dad <unknown>
# #9 0x63beb2c846d8 <unknown>
# #10 0x63beb2cb3f4e <unknown>
# #11 0x63beb2cd2866 <unknown>
# #12 0x63beb2cb3b23 <unknown>
# #13 0x63beb2c82990 <unknown>
# #14 0x63beb2c8396e <unknown>
# #15 0x63beb30f816b <unknown>
# #16 0x63beb30fbf68 <unknown>
# #17 0x63beb30e564c <unknown>
# #18 0x63beb30fcae7 <unknown>
# #19 0x63beb30ca4af <unknown>
# #20 0x63beb311a4f8 <unknown>
# #21 0x63beb311a6c0 <unknown>
# #22 0x63beb312af26 <unknown>
# #23 0x72349689ca94 <unknown>
# #24 0x723496929c3c <unknown>
#
# Traceback (most recent call last):
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/base_crawler.py", line 219, in start
#     self._handle_parse_url(url)
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/base_crawler.py", line 271, in _handle_parse_url
#     data = self.parse()
#            ^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/page_crawler/crawler.py", line 162, in parse
#     post = self.parse_post(i, post_div)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/page_crawler/crawler.py", line 185, in parse_post
#     owner_loc_anchors = profile_div.find_elements(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webelement.py", line 761, in find_elements
#     return self._execute(Command.FIND_CHILD_ELEMENTS,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webelement.py", line 710, in _execute
#     return self._parent.execute(command, params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 424, in execute
#     self.error_handler.check_response(response)
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.InvalidSelectorException: Message: invalid selector
# from javascript error: {"status":32,"value":"Unable to locate an element with the xpath expression (((//div[@class='x9f619 x1n2onr6 x1ja2u2z xeuugli xs83m0k xjl7jj x1xmf6yo x1emribx x1e56ztr x1i64zmx x19h7ccj xu9j1y6 x7ep2pv']/div)[last()]/div/div[@class='x1yztbdb x1n2onr6 xh8yej3 x1ja2u2z'])[1]//h2/../../../../div//a because of the following error:\nSyntaxError: Failed to execute 'evaluate' on 'Document': The string '(((//div[@class='x9f619 x1n2onr6 x1ja2u2z xeuugli xs83m0k xjl7jj x1xmf6yo x1emribx x1e56ztr x1i64zmx x19h7ccj xu9j1y6 x7ep2pv']/div)[last()]/div/div[@class='x1yztbdb x1n2onr6 xh8yej3 x1ja2u2z'])[1]//h2/../../../../div//a' is not a valid XPath expression."}
#   (Session info: chrome=130.0.6723.58)
# Stacktrace:
# #0 0x63beb312c0aa <unknown>
# #1 0x63beb2c431a0 <unknown>
# #2 0x63beb2c48ef3 <unknown>
# #3 0x63beb2c4aba5 <unknown>
# #4 0x63beb2c4ac2c <unknown>
# #5 0x63beb2c8f965 <unknown>
# #6 0x63beb2c8ffa1 <unknown>
# #7 0x63beb2c84b53 <unknown>
# #8 0x63beb2cb3dad <unknown>
# #9 0x63beb2c846d8 <unknown>
# #10 0x63beb2cb3f4e <unknown>
# #11 0x63beb2cd2866 <unknown>
# #12 0x63beb2cb3b23 <unknown>
# #13 0x63beb2c82990 <unknown>
# #14 0x63beb2c8396e <unknown>
# #15 0x63beb30f816b <unknown>
# #16 0x63beb30fbf68 <unknown>
# #17 0x63beb30e564c <unknown>
# #18 0x63beb30fcae7 <unknown>
# #19 0x63beb30ca4af <unknown>
# #20 0x63beb311a4f8 <unknown>
# #21 0x63beb311a6c0 <unknown>
# #22 0x63beb312af26 <unknown>
# #23 0x72349689ca94 <unknown>
# #24 0x723496929c3c <unknown>
#
#
# [Page Crawler][WARNING][20-10 18:03:02]: Attempting 3rd retrial...
# [Page Crawler][INFO][20-10 18:03:09]: Matched as URL for navigation: https://www.facebook.com/UnderArmourVietnam
# [Page Crawler][INFO][20-10 18:03:11]: Enqueuing 0 new navigation URLs
# [Page Crawler][INFO][20-10 18:03:11]: Selectively enqueuing 0 new parsing URLs
# [Page Crawler][INFO][20-10 18:03:11]: Matched as URL for parsing: https://www.facebook.com/UnderArmourVietnam
# [Page Crawler][INFO][20-10 18:03:13]: Opened new tab to https://www.facebook.com/UnderArmourVietnam
# RAM Usage (GB):  53%|████████████▎          | 8.2/15.33 [01:30<01:18, 11.04s/it]
# [Page Crawler][ERROR][20-10 18:04:43]: Restore https://www.facebook.com/UnderArmourVietnam to queue due to error:
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"(((//div[@class='x9f619 x1n2onr6 x1ja2u2z xeuugli xs83m0k xjl7jj x1xmf6yo x1emribx x1e56ztr x1i64zmx x19h7ccj xu9j1y6 x7ep2pv']/div)[last()]/div/div[@class='x1yztbdb x1n2onr6 xh8yej3 x1ja2u2z'])[last()]//h2/../../../../div)[2]//a"}
#   (Session info: chrome=130.0.6723.58)
# Stacktrace:
# #0 0x63beb312c0aa <unknown>
# #1 0x63beb2c431a0 <unknown>
# #2 0x63beb2c8fd06 <unknown>
# #3 0x63beb2c8ffa1 <unknown>
# #4 0x63beb2cd5344 <unknown>
# #5 0x63beb2cb3dad <unknown>
# #6 0x63beb2cd2866 <unknown>
# #7 0x63beb2cb3b23 <unknown>
# #8 0x63beb2c82990 <unknown>
# #9 0x63beb2c8396e <unknown>
# #10 0x63beb30f816b <unknown>
# #11 0x63beb30fbf68 <unknown>
# #12 0x63beb30e564c <unknown>
# #13 0x63beb30fcae7 <unknown>
# #14 0x63beb30ca4af <unknown>
# #15 0x63beb311a4f8 <unknown>
# #16 0x63beb311a6c0 <unknown>
# #17 0x63beb312af26 <unknown>
# #18 0x72349689ca94 <unknown>
# #19 0x723496929c3c <unknown>
#
# Traceback (most recent call last):
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/base_crawler.py", line 219, in start
#     self._handle_parse_url(url)
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/base_crawler.py", line 271, in _handle_parse_url
#     data = self.parse()
#            ^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/page_crawler/crawler.py", line 137, in parse
#     self.post_collect_criteria.update_progress(self.chrome)
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/page_crawler/crawler.py", line 67, in update_progress
#     last_post_datetime_a = driver.find_element(
#                            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 1244, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 424, in execute
#     self.error_handler.check_response(response)
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"(((//div[@class='x9f619 x1n2onr6 x1ja2u2z xeuugli xs83m0k xjl7jj x1xmf6yo x1emribx x1e56ztr x1i64zmx x19h7ccj xu9j1y6 x7ep2pv']/div)[last()]/div/div[@class='x1yztbdb x1n2onr6 xh8yej3 x1ja2u2z'])[last()]//h2/../../../../div)[2]//a"}
#   (Session info: chrome=130.0.6723.58)
# Stacktrace:
# #0 0x63beb312c0aa <unknown>
# #1 0x63beb2c431a0 <unknown>
# #2 0x63beb2c8fd06 <unknown>
# #3 0x63beb2c8ffa1 <unknown>
# #4 0x63beb2cd5344 <unknown>
# #5 0x63beb2cb3dad <unknown>
# #6 0x63beb2cd2866 <unknown>
# #7 0x63beb2cb3b23 <unknown>
# #8 0x63beb2c82990 <unknown>
# #9 0x63beb2c8396e <unknown>
# #10 0x63beb30f816b <unknown>
# #11 0x63beb30fbf68 <unknown>
# #12 0x63beb30e564c <unknown>
# #13 0x63beb30fcae7 <unknown>
# #14 0x63beb30ca4af <unknown>
# #15 0x63beb311a4f8 <unknown>
# #16 0x63beb311a6c0 <unknown>
# #17 0x63beb312af26 <unknown>
# #18 0x72349689ca94 <unknown>
# #19 0x723496929c3c <unknown>
#
#
# [Page Crawler][WARNING][20-10 18:04:43]: Attempting 4th retrial...
# [Page Crawler][INFO][20-10 18:04:50]: Matched as URL for navigation: https://www.facebook.com/UnderArmourVietnam
# [Page Crawler][INFO][20-10 18:04:52]: Enqueuing 0 new navigation URLs
# [Page Crawler][INFO][20-10 18:04:52]: Selectively enqueuing 0 new parsing URLs
# [Page Crawler][INFO][20-10 18:04:52]: Matched as URL for parsing: https://www.facebook.com/UnderArmourVietnam
# [Page Crawler][INFO][20-10 18:04:54]: Opened new tab to https://www.facebook.com/UnderArmourVietnam
# RAM Usage (GB):  54%|███████████▊          | 8.25/15.33 [01:30<01:17, 10.98s/it]
# [Page Crawler][ERROR][20-10 18:06:25]: Restore https://www.facebook.com/UnderArmourVietnam to queue due to error:
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"(((//div[@class='x9f619 x1n2onr6 x1ja2u2z xeuugli xs83m0k xjl7jj x1xmf6yo x1emribx x1e56ztr x1i64zmx x19h7ccj xu9j1y6 x7ep2pv']/div)[last()]/div/div[@class='x1yztbdb x1n2onr6 xh8yej3 x1ja2u2z'])[last()]//h2/../../../../div)[2]//a"}
#   (Session info: chrome=130.0.6723.58)
# Stacktrace:
# #0 0x63beb312c0aa <unknown>
# #1 0x63beb2c431a0 <unknown>
# #2 0x63beb2c8fd06 <unknown>
# #3 0x63beb2c8ffa1 <unknown>
# #4 0x63beb2cd5344 <unknown>
# #5 0x63beb2cb3dad <unknown>
# #6 0x63beb2cd2866 <unknown>
# #7 0x63beb2cb3b23 <unknown>
# #8 0x63beb2c82990 <unknown>
# #9 0x63beb2c8396e <unknown>
# #10 0x63beb30f816b <unknown>
# #11 0x63beb30fbf68 <unknown>
# #12 0x63beb30e564c <unknown>
# #13 0x63beb30fcae7 <unknown>
# #14 0x63beb30ca4af <unknown>
# #15 0x63beb311a4f8 <unknown>
# #16 0x63beb311a6c0 <unknown>
# #17 0x63beb312af26 <unknown>
# #18 0x72349689ca94 <unknown>
# #19 0x723496929c3c <unknown>
#
# Traceback (most recent call last):
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/base_crawler.py", line 219, in start
#     self._handle_parse_url(url)
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/base_crawler.py", line 271, in _handle_parse_url
#     data = self.parse()
#            ^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/page_crawler/crawler.py", line 137, in parse
#     self.post_collect_criteria.update_progress(self.chrome)
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/page_crawler/crawler.py", line 67, in update_progress
#     last_post_datetime_a = driver.find_element(
#                            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 1244, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 424, in execute
#     self.error_handler.check_response(response)
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"(((//div[@class='x9f619 x1n2onr6 x1ja2u2z xeuugli xs83m0k xjl7jj x1xmf6yo x1emribx x1e56ztr x1i64zmx x19h7ccj xu9j1y6 x7ep2pv']/div)[last()]/div/div[@class='x1yztbdb x1n2onr6 xh8yej3 x1ja2u2z'])[last()]//h2/../../../../div)[2]//a"}
#   (Session info: chrome=130.0.6723.58)
# Stacktrace:
# #0 0x63beb312c0aa <unknown>
# #1 0x63beb2c431a0 <unknown>
# #2 0x63beb2c8fd06 <unknown>
# #3 0x63beb2c8ffa1 <unknown>
# #4 0x63beb2cd5344 <unknown>
# #5 0x63beb2cb3dad <unknown>
# #6 0x63beb2cd2866 <unknown>
# #7 0x63beb2cb3b23 <unknown>
# #8 0x63beb2c82990 <unknown>
# #9 0x63beb2c8396e <unknown>
# #10 0x63beb30f816b <unknown>
# #11 0x63beb30fbf68 <unknown>
# #12 0x63beb30e564c <unknown>
# #13 0x63beb30fcae7 <unknown>
# #14 0x63beb30ca4af <unknown>
# #15 0x63beb311a4f8 <unknown>
# #16 0x63beb311a6c0 <unknown>
# #17 0x63beb312af26 <unknown>
# #18 0x72349689ca94 <unknown>
# #19 0x723496929c3c <unknown>
#
#
# [Page Crawler][WARNING][20-10 18:06:25]: Attempting 5th retrial...
# [Page Crawler][INFO][20-10 18:06:31]: Matched as URL for navigation: https://www.facebook.com/UnderArmourVietnam
# [Page Crawler][INFO][20-10 18:06:33]: Enqueuing 0 new navigation URLs
# [Page Crawler][INFO][20-10 18:06:33]: Selectively enqueuing 0 new parsing URLs
# [Page Crawler][INFO][20-10 18:06:33]: Matched as URL for parsing: https://www.facebook.com/UnderArmourVietnam
# [Page Crawler][INFO][20-10 18:06:35]: Opened new tab to https://www.facebook.com/UnderArmourVietnam
# RAM Usage (GB):  54%|████████████▍          | 8.3/15.33 [00:00<00:00,  9.72it/s]
# [Page Crawler][ERROR][20-10 18:06:36]: Restore https://www.facebook.com/UnderArmourVietnam to queue due to error:
# StaleElementReferenceException: Message: stale element reference: stale element not found in the current frame
#   (Session info: chrome=130.0.6723.58)
# Stacktrace:
# #0 0x63beb312c0aa <unknown>
# #1 0x63beb2c431a0 <unknown>
# #2 0x63beb2c48ef3 <unknown>
# #3 0x63beb2c4aba5 <unknown>
# #4 0x63beb2c4ac2c <unknown>
# #5 0x63beb2c95dfe <unknown>
# #6 0x63beb2c95226 <unknown>
# #7 0x63beb2cdb34a <unknown>
# #8 0x63beb2cb3d82 <unknown>
# #9 0x63beb2cd2866 <unknown>
# #10 0x63beb2cb3b23 <unknown>
# #11 0x63beb2c82990 <unknown>
# #12 0x63beb2c8396e <unknown>
# #13 0x63beb30f816b <unknown>
# #14 0x63beb30fbf68 <unknown>
# #15 0x63beb30e564c <unknown>
# #16 0x63beb30fcae7 <unknown>
# #17 0x63beb30ca4af <unknown>
# #18 0x63beb311a4f8 <unknown>
# #19 0x63beb311a6c0 <unknown>
# #20 0x63beb312af26 <unknown>
# #21 0x72349689ca94 <unknown>
# #22 0x723496929c3c <unknown>
#
# Traceback (most recent call last):
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/base_crawler.py", line 219, in start
#     self._handle_parse_url(url)
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/base_crawler.py", line 271, in _handle_parse_url
#     data = self.parse()
#            ^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/page_crawler/crawler.py", line 137, in parse
#     self.post_collect_criteria.update_progress(self.chrome)
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/page_crawler/crawler.py", line 71, in update_progress
#     ActionChains(driver).move_to_element(last_post_datetime_a).perform()
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/common/action_chains.py", line 75, in perform
#     self.w3c_actions.perform()
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/common/actions/action_builder.py", line 77, in perform
#     self.driver.execute(Command.W3C_ACTIONS, enc)
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 424, in execute
#     self.error_handler.check_response(response)
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: stale element reference: stale element not found in the current frame
#   (Session info: chrome=130.0.6723.58)
# Stacktrace:
# #0 0x63beb312c0aa <unknown>
# #1 0x63beb2c431a0 <unknown>
# #2 0x63beb2c48ef3 <unknown>
# #3 0x63beb2c4aba5 <unknown>
# #4 0x63beb2c4ac2c <unknown>
# #5 0x63beb2c95dfe <unknown>
# #6 0x63beb2c95226 <unknown>
# #7 0x63beb2cdb34a <unknown>
# #8 0x63beb2cb3d82 <unknown>
# #9 0x63beb2cd2866 <unknown>
# #10 0x63beb2cb3b23 <unknown>
# #11 0x63beb2c82990 <unknown>
# #12 0x63beb2c8396e <unknown>
# #13 0x63beb30f816b <unknown>
# #14 0x63beb30fbf68 <unknown>
# #15 0x63beb30e564c <unknown>
# #16 0x63beb30fcae7 <unknown>
# #17 0x63beb30ca4af <unknown>
# #18 0x63beb311a4f8 <unknown>
# #19 0x63beb311a6c0 <unknown>
# #20 0x63beb312af26 <unknown>
# #21 0x72349689ca94 <unknown>
# #22 0x723496929c3c <unknown>
#
#
# [Page Crawler][WARNING][20-10 18:06:36]: Attempting 6th retrial...
# [Page Crawler][ERROR][20-10 18:06:43]: Closing driver due to an error occured...
