# %%
# !python3 main.py \
    --chromedriver=/home/ptdat/.wdm/drivers/chromedriver/linux64/130.0.6723.58/chromedriver-linux64/chromedriver \
    --crawler=page_crawler \
    --user=user1 \
    --crawler-dir=./data/ \
    --sleep-weibull-lambda=7 \
    --max-loading-wait=90 \
    --cookies-dir=./cookies/ \
    --secrets-json=./secrets.json \
    # --headless \
    --error-screenshot-dir=./error-screenshots/ \
    --max-error-trials=5
# Out:
# [Page Crawler][INFO][24-10 19:42:57]: Initializing...
# [Page Crawler][INFO][24-10 19:42:59]: Driver started
# [Page Crawler][INFO][24-10 19:42:59]: Ensuring user logging in
# [Page Crawler][INFO][24-10 19:42:59]: Found user's credentials cached as cookies
# [Page Crawler][INFO][24-10 19:43:01]: Saved/Refreshed cookies
# [Page Crawler][INFO][24-10 19:43:01]: Matched as URL for navigation: https://www.facebook.com/UnderArmourVietnam
# [Page Crawler][INFO][24-10 19:43:05]: Enqueuing 0 new navigation URLs
# [Page Crawler][INFO][24-10 19:43:05]: Selectively enqueuing 0 new parsing URLs
# [Page Crawler][INFO][24-10 19:43:05]: Matched as URL for parsing: https://www.facebook.com/UnderArmourVietnam
# [Page Crawler][INFO][24-10 19:43:07]: Opened new tab to https://www.facebook.com/UnderArmourVietnam
# RAM Usage (GB):  35%|▋ | 5.43/15.33 [01:16<02:19, 14.14s/it, # Loaded posts: 28]
# [Page Crawler][INFO][24-10 19:44:23]: Post collect stopping criteria has met with threshold of 2024-09-01 00:00:00
# [Page Crawler][INFO][24-10 19:44:24]: Located 31 posts
# Parsing posts:   0%|                                     | 0/31 [00:01<?, ?it/s]
# [Page Crawler][ERROR][24-10 19:44:25]: Restore https://www.facebook.com/UnderArmourVietnam to queue due to error:
# InvalidSelectorException: Message: invalid selector
# from javascript error: {"status":32,"value":"Unable to locate an element with the xpath expression (((//div[@class='x9f619 x1n2onr6 x1ja2u2z xeuugli xs83m0k xjl7jj x1xmf6yo x1emribx x1e56ztr x1i64zmx x19h7ccj xu9j1y6 x7ep2pv']/div)[last()]/div/div[@class='x1yztbdb x1n2onr6 xh8yej3 x1ja2u2z'])[1]//h2/../../../../div//a because of the following error:\nSyntaxError: Failed to execute 'evaluate' on 'Document': The string '(((//div[@class='x9f619 x1n2onr6 x1ja2u2z xeuugli xs83m0k xjl7jj x1xmf6yo x1emribx x1e56ztr x1i64zmx x19h7ccj xu9j1y6 x7ep2pv']/div)[last()]/div/div[@class='x1yztbdb x1n2onr6 xh8yej3 x1ja2u2z'])[1]//h2/../../../../div//a' is not a valid XPath expression."}
#   (Session info: chrome=130.0.6723.69)
# Stacktrace:
# #0 0x5d24f88e80aa <unknown>
# #1 0x5d24f83ff1a0 <unknown>
# #2 0x5d24f8404ef3 <unknown>
# #3 0x5d24f8406ba5 <unknown>
# #4 0x5d24f8406c2c <unknown>
# #5 0x5d24f844b965 <unknown>
# #6 0x5d24f844bfa1 <unknown>
# #7 0x5d24f8440b53 <unknown>
# #8 0x5d24f846fdad <unknown>
# #9 0x5d24f84406d8 <unknown>
# #10 0x5d24f846ff4e <unknown>
# #11 0x5d24f848e866 <unknown>
# #12 0x5d24f846fb23 <unknown>
# #13 0x5d24f843e990 <unknown>
# #14 0x5d24f843f96e <unknown>
# #15 0x5d24f88b416b <unknown>
# #16 0x5d24f88b7f68 <unknown>
# #17 0x5d24f88a164c <unknown>
# #18 0x5d24f88b8ae7 <unknown>
# #19 0x5d24f88864af <unknown>
# #20 0x5d24f88d64f8 <unknown>
# #21 0x5d24f88d66c0 <unknown>
# #22 0x5d24f88e6f26 <unknown>
# #23 0x74ea5169ca94 <unknown>
# #24 0x74ea51729c3c <unknown>
#
# Traceback (most recent call last):
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/base_crawler.py", line 219, in start
#     self._handle_parse_url(url)
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/base_crawler.py", line 271, in _handle_parse_url
#     data = self.parse()
#            ^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/page_crawler/crawler.py", line 162, in parse
#     post = self.parse_post(i, post_div)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/page_crawler/crawler.py", line 185, in parse_post
#     owner_loc_anchors = profile_div.find_elements(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webelement.py", line 761, in find_elements
#     return self._execute(Command.FIND_CHILD_ELEMENTS,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webelement.py", line 710, in _execute
#     return self._parent.execute(command, params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 424, in execute
#     self.error_handler.check_response(response)
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.InvalidSelectorException: Message: invalid selector
# from javascript error: {"status":32,"value":"Unable to locate an element with the xpath expression (((//div[@class='x9f619 x1n2onr6 x1ja2u2z xeuugli xs83m0k xjl7jj x1xmf6yo x1emribx x1e56ztr x1i64zmx x19h7ccj xu9j1y6 x7ep2pv']/div)[last()]/div/div[@class='x1yztbdb x1n2onr6 xh8yej3 x1ja2u2z'])[1]//h2/../../../../div//a because of the following error:\nSyntaxError: Failed to execute 'evaluate' on 'Document': The string '(((//div[@class='x9f619 x1n2onr6 x1ja2u2z xeuugli xs83m0k xjl7jj x1xmf6yo x1emribx x1e56ztr x1i64zmx x19h7ccj xu9j1y6 x7ep2pv']/div)[last()]/div/div[@class='x1yztbdb x1n2onr6 xh8yej3 x1ja2u2z'])[1]//h2/../../../../div//a' is not a valid XPath expression."}
#   (Session info: chrome=130.0.6723.69)
# Stacktrace:
# #0 0x5d24f88e80aa <unknown>
# #1 0x5d24f83ff1a0 <unknown>
# #2 0x5d24f8404ef3 <unknown>
# #3 0x5d24f8406ba5 <unknown>
# #4 0x5d24f8406c2c <unknown>
# #5 0x5d24f844b965 <unknown>
# #6 0x5d24f844bfa1 <unknown>
# #7 0x5d24f8440b53 <unknown>
# #8 0x5d24f846fdad <unknown>
# #9 0x5d24f84406d8 <unknown>
# #10 0x5d24f846ff4e <unknown>
# #11 0x5d24f848e866 <unknown>
# #12 0x5d24f846fb23 <unknown>
# #13 0x5d24f843e990 <unknown>
# #14 0x5d24f843f96e <unknown>
# #15 0x5d24f88b416b <unknown>
# #16 0x5d24f88b7f68 <unknown>
# #17 0x5d24f88a164c <unknown>
# #18 0x5d24f88b8ae7 <unknown>
# #19 0x5d24f88864af <unknown>
# #20 0x5d24f88d64f8 <unknown>
# #21 0x5d24f88d66c0 <unknown>
# #22 0x5d24f88e6f26 <unknown>
# #23 0x74ea5169ca94 <unknown>
# #24 0x74ea51729c3c <unknown>
#
#
# [Page Crawler][WARNING][24-10 19:44:25]: Attempting 1st retrial...
# [Page Crawler][INFO][24-10 19:44:33]: Matched as URL for navigation: https://www.facebook.com/UnderArmourVietnam
# [Page Crawler][INFO][24-10 19:44:35]: Enqueuing 0 new navigation URLs
# [Page Crawler][INFO][24-10 19:44:35]: Selectively enqueuing 0 new parsing URLs
# [Page Crawler][INFO][24-10 19:44:35]: Matched as URL for parsing: https://www.facebook.com/UnderArmourVietnam
# [Page Crawler][INFO][24-10 19:44:37]: Opened new tab to https://www.facebook.com/UnderArmourVietnam
# RAM Usage (GB):  35%|███████▊              | 5.43/15.33 [00:01<00:02,  4.85it/s]
# [Page Crawler][ERROR][24-10 19:44:38]: Restore https://www.facebook.com/UnderArmourVietnam to queue due to error:
# StaleElementReferenceException: Message: stale element reference: stale element not found in the current frame
#   (Session info: chrome=130.0.6723.69)
# Stacktrace:
# #0 0x5d24f88e80aa <unknown>
# #1 0x5d24f83ff1a0 <unknown>
# #2 0x5d24f8404ef3 <unknown>
# #3 0x5d24f8406ba5 <unknown>
# #4 0x5d24f8406c2c <unknown>
# #5 0x5d24f8451dfe <unknown>
# #6 0x5d24f8451226 <unknown>
# #7 0x5d24f849734a <unknown>
# #8 0x5d24f846fd82 <unknown>
# #9 0x5d24f848e866 <unknown>
# #10 0x5d24f846fb23 <unknown>
# #11 0x5d24f843e990 <unknown>
# #12 0x5d24f843f96e <unknown>
# #13 0x5d24f88b416b <unknown>
# #14 0x5d24f88b7f68 <unknown>
# #15 0x5d24f88a164c <unknown>
# #16 0x5d24f88b8ae7 <unknown>
# #17 0x5d24f88864af <unknown>
# #18 0x5d24f88d64f8 <unknown>
# #19 0x5d24f88d66c0 <unknown>
# #20 0x5d24f88e6f26 <unknown>
# #21 0x74ea5169ca94 <unknown>
# #22 0x74ea51729c3c <unknown>
#
# Traceback (most recent call last):
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/base_crawler.py", line 219, in start
#     self._handle_parse_url(url)
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/base_crawler.py", line 271, in _handle_parse_url
#     data = self.parse()
#            ^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/page_crawler/crawler.py", line 137, in parse
#     self.post_collect_criteria.update_progress(self.chrome)
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/page_crawler/crawler.py", line 71, in update_progress
#     ActionChains(driver).move_to_element(last_post_datetime_a).perform()
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/common/action_chains.py", line 75, in perform
#     self.w3c_actions.perform()
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/common/actions/action_builder.py", line 77, in perform
#     self.driver.execute(Command.W3C_ACTIONS, enc)
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 424, in execute
#     self.error_handler.check_response(response)
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: stale element reference: stale element not found in the current frame
#   (Session info: chrome=130.0.6723.69)
# Stacktrace:
# #0 0x5d24f88e80aa <unknown>
# #1 0x5d24f83ff1a0 <unknown>
# #2 0x5d24f8404ef3 <unknown>
# #3 0x5d24f8406ba5 <unknown>
# #4 0x5d24f8406c2c <unknown>
# #5 0x5d24f8451dfe <unknown>
# #6 0x5d24f8451226 <unknown>
# #7 0x5d24f849734a <unknown>
# #8 0x5d24f846fd82 <unknown>
# #9 0x5d24f848e866 <unknown>
# #10 0x5d24f846fb23 <unknown>
# #11 0x5d24f843e990 <unknown>
# #12 0x5d24f843f96e <unknown>
# #13 0x5d24f88b416b <unknown>
# #14 0x5d24f88b7f68 <unknown>
# #15 0x5d24f88a164c <unknown>
# #16 0x5d24f88b8ae7 <unknown>
# #17 0x5d24f88864af <unknown>
# #18 0x5d24f88d64f8 <unknown>
# #19 0x5d24f88d66c0 <unknown>
# #20 0x5d24f88e6f26 <unknown>
# #21 0x74ea5169ca94 <unknown>
# #22 0x74ea51729c3c <unknown>
#
#
# [Page Crawler][WARNING][24-10 19:44:38]: Attempting 2nd retrial...
# [Page Crawler][INFO][24-10 19:44:45]: Matched as URL for navigation: https://www.facebook.com/UnderArmourVietnam
# [Page Crawler][INFO][24-10 19:44:47]: Enqueuing 0 new navigation URLs
# [Page Crawler][INFO][24-10 19:44:47]: Selectively enqueuing 0 new parsing URLs
# [Page Crawler][INFO][24-10 19:44:47]: Matched as URL for parsing: https://www.facebook.com/UnderArmourVietnam
# [Page Crawler][INFO][24-10 19:44:49]: Opened new tab to https://www.facebook.com/UnderArmourVietnam
# RAM Usage (GB):  35%|███████▊              | 5.44/15.33 [00:00<00:01,  6.07it/s]
# [Page Crawler][ERROR][24-10 19:44:50]: Restore https://www.facebook.com/UnderArmourVietnam to queue due to error:
# StaleElementReferenceException: Message: stale element reference: stale element not found in the current frame
#   (Session info: chrome=130.0.6723.69)
# Stacktrace:
# #0 0x5d24f88e80aa <unknown>
# #1 0x5d24f83ff1a0 <unknown>
# #2 0x5d24f8404ef3 <unknown>
# #3 0x5d24f8406ba5 <unknown>
# #4 0x5d24f8406c2c <unknown>
# #5 0x5d24f8451dfe <unknown>
# #6 0x5d24f8451226 <unknown>
# #7 0x5d24f849734a <unknown>
# #8 0x5d24f846fd82 <unknown>
# #9 0x5d24f848e866 <unknown>
# #10 0x5d24f846fb23 <unknown>
# #11 0x5d24f843e990 <unknown>
# #12 0x5d24f843f96e <unknown>
# #13 0x5d24f88b416b <unknown>
# #14 0x5d24f88b7f68 <unknown>
# #15 0x5d24f88a164c <unknown>
# #16 0x5d24f88b8ae7 <unknown>
# #17 0x5d24f88864af <unknown>
# #18 0x5d24f88d64f8 <unknown>
# #19 0x5d24f88d66c0 <unknown>
# #20 0x5d24f88e6f26 <unknown>
# #21 0x74ea5169ca94 <unknown>
# #22 0x74ea51729c3c <unknown>
#
# Traceback (most recent call last):
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/base_crawler.py", line 219, in start
#     self._handle_parse_url(url)
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/base_crawler.py", line 271, in _handle_parse_url
#     data = self.parse()
#            ^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/page_crawler/crawler.py", line 137, in parse
#     self.post_collect_criteria.update_progress(self.chrome)
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/page_crawler/crawler.py", line 71, in update_progress
#     ActionChains(driver).move_to_element(last_post_datetime_a).perform()
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/common/action_chains.py", line 75, in perform
#     self.w3c_actions.perform()
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/common/actions/action_builder.py", line 77, in perform
#     self.driver.execute(Command.W3C_ACTIONS, enc)
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 424, in execute
#     self.error_handler.check_response(response)
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.StaleElementReferenceException: Message: stale element reference: stale element not found in the current frame
#   (Session info: chrome=130.0.6723.69)
# Stacktrace:
# #0 0x5d24f88e80aa <unknown>
# #1 0x5d24f83ff1a0 <unknown>
# #2 0x5d24f8404ef3 <unknown>
# #3 0x5d24f8406ba5 <unknown>
# #4 0x5d24f8406c2c <unknown>
# #5 0x5d24f8451dfe <unknown>
# #6 0x5d24f8451226 <unknown>
# #7 0x5d24f849734a <unknown>
# #8 0x5d24f846fd82 <unknown>
# #9 0x5d24f848e866 <unknown>
# #10 0x5d24f846fb23 <unknown>
# #11 0x5d24f843e990 <unknown>
# #12 0x5d24f843f96e <unknown>
# #13 0x5d24f88b416b <unknown>
# #14 0x5d24f88b7f68 <unknown>
# #15 0x5d24f88a164c <unknown>
# #16 0x5d24f88b8ae7 <unknown>
# #17 0x5d24f88864af <unknown>
# #18 0x5d24f88d64f8 <unknown>
# #19 0x5d24f88d66c0 <unknown>
# #20 0x5d24f88e6f26 <unknown>
# #21 0x74ea5169ca94 <unknown>
# #22 0x74ea51729c3c <unknown>
#
#
# [Page Crawler][WARNING][24-10 19:44:50]: Attempting 3rd retrial...
# [Page Crawler][INFO][24-10 19:44:55]: Matched as URL for navigation: https://www.facebook.com/UnderArmourVietnam
# [Page Crawler][INFO][24-10 19:44:57]: Enqueuing 0 new navigation URLs
# [Page Crawler][INFO][24-10 19:44:57]: Selectively enqueuing 0 new parsing URLs
# [Page Crawler][INFO][24-10 19:44:57]: Matched as URL for parsing: https://www.facebook.com/UnderArmourVietnam
# [Page Crawler][INFO][24-10 19:44:59]: Opened new tab to https://www.facebook.com/UnderArmourVietnam
# RAM Usage (GB):  37%|▋ | 5.63/15.33 [01:16<02:11, 13.53s/it, # Loaded posts: 28]
# [Page Crawler][INFO][24-10 19:46:15]: Post collect stopping criteria has met with threshold of 2024-09-01 00:00:00
# [Page Crawler][INFO][24-10 19:46:15]: Located 31 posts
# Parsing posts:   0%|                                     | 0/31 [00:01<?, ?it/s]
# [Page Crawler][ERROR][24-10 19:46:17]: Restore https://www.facebook.com/UnderArmourVietnam to queue due to error:
# InvalidSelectorException: Message: invalid selector
# from javascript error: {"status":32,"value":"Unable to locate an element with the xpath expression (((//div[@class='x9f619 x1n2onr6 x1ja2u2z xeuugli xs83m0k xjl7jj x1xmf6yo x1emribx x1e56ztr x1i64zmx x19h7ccj xu9j1y6 x7ep2pv']/div)[last()]/div/div[@class='x1yztbdb x1n2onr6 xh8yej3 x1ja2u2z'])[1]//h2/../../../../div//a because of the following error:\nSyntaxError: Failed to execute 'evaluate' on 'Document': The string '(((//div[@class='x9f619 x1n2onr6 x1ja2u2z xeuugli xs83m0k xjl7jj x1xmf6yo x1emribx x1e56ztr x1i64zmx x19h7ccj xu9j1y6 x7ep2pv']/div)[last()]/div/div[@class='x1yztbdb x1n2onr6 xh8yej3 x1ja2u2z'])[1]//h2/../../../../div//a' is not a valid XPath expression."}
#   (Session info: chrome=130.0.6723.69)
# Stacktrace:
# #0 0x5d24f88e80aa <unknown>
# #1 0x5d24f83ff1a0 <unknown>
# #2 0x5d24f8404ef3 <unknown>
# #3 0x5d24f8406ba5 <unknown>
# #4 0x5d24f8406c2c <unknown>
# #5 0x5d24f844b965 <unknown>
# #6 0x5d24f844bfa1 <unknown>
# #7 0x5d24f8440b53 <unknown>
# #8 0x5d24f846fdad <unknown>
# #9 0x5d24f84406d8 <unknown>
# #10 0x5d24f846ff4e <unknown>
# #11 0x5d24f848e866 <unknown>
# #12 0x5d24f846fb23 <unknown>
# #13 0x5d24f843e990 <unknown>
# #14 0x5d24f843f96e <unknown>
# #15 0x5d24f88b416b <unknown>
# #16 0x5d24f88b7f68 <unknown>
# #17 0x5d24f88a164c <unknown>
# #18 0x5d24f88b8ae7 <unknown>
# #19 0x5d24f88864af <unknown>
# #20 0x5d24f88d64f8 <unknown>
# #21 0x5d24f88d66c0 <unknown>
# #22 0x5d24f88e6f26 <unknown>
# #23 0x74ea5169ca94 <unknown>
# #24 0x74ea51729c3c <unknown>
#
# Traceback (most recent call last):
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/base_crawler.py", line 219, in start
#     self._handle_parse_url(url)
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/base_crawler.py", line 271, in _handle_parse_url
#     data = self.parse()
#            ^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/page_crawler/crawler.py", line 162, in parse
#     post = self.parse_post(i, post_div)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/page_crawler/crawler.py", line 185, in parse_post
#     owner_loc_anchors = profile_div.find_elements(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webelement.py", line 761, in find_elements
#     return self._execute(Command.FIND_CHILD_ELEMENTS,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webelement.py", line 710, in _execute
#     return self._parent.execute(command, params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 424, in execute
#     self.error_handler.check_response(response)
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.InvalidSelectorException: Message: invalid selector
# from javascript error: {"status":32,"value":"Unable to locate an element with the xpath expression (((//div[@class='x9f619 x1n2onr6 x1ja2u2z xeuugli xs83m0k xjl7jj x1xmf6yo x1emribx x1e56ztr x1i64zmx x19h7ccj xu9j1y6 x7ep2pv']/div)[last()]/div/div[@class='x1yztbdb x1n2onr6 xh8yej3 x1ja2u2z'])[1]//h2/../../../../div//a because of the following error:\nSyntaxError: Failed to execute 'evaluate' on 'Document': The string '(((//div[@class='x9f619 x1n2onr6 x1ja2u2z xeuugli xs83m0k xjl7jj x1xmf6yo x1emribx x1e56ztr x1i64zmx x19h7ccj xu9j1y6 x7ep2pv']/div)[last()]/div/div[@class='x1yztbdb x1n2onr6 xh8yej3 x1ja2u2z'])[1]//h2/../../../../div//a' is not a valid XPath expression."}
#   (Session info: chrome=130.0.6723.69)
# Stacktrace:
# #0 0x5d24f88e80aa <unknown>
# #1 0x5d24f83ff1a0 <unknown>
# #2 0x5d24f8404ef3 <unknown>
# #3 0x5d24f8406ba5 <unknown>
# #4 0x5d24f8406c2c <unknown>
# #5 0x5d24f844b965 <unknown>
# #6 0x5d24f844bfa1 <unknown>
# #7 0x5d24f8440b53 <unknown>
# #8 0x5d24f846fdad <unknown>
# #9 0x5d24f84406d8 <unknown>
# #10 0x5d24f846ff4e <unknown>
# #11 0x5d24f848e866 <unknown>
# #12 0x5d24f846fb23 <unknown>
# #13 0x5d24f843e990 <unknown>
# #14 0x5d24f843f96e <unknown>
# #15 0x5d24f88b416b <unknown>
# #16 0x5d24f88b7f68 <unknown>
# #17 0x5d24f88a164c <unknown>
# #18 0x5d24f88b8ae7 <unknown>
# #19 0x5d24f88864af <unknown>
# #20 0x5d24f88d64f8 <unknown>
# #21 0x5d24f88d66c0 <unknown>
# #22 0x5d24f88e6f26 <unknown>
# #23 0x74ea5169ca94 <unknown>
# #24 0x74ea51729c3c <unknown>
#
#
# [Page Crawler][WARNING][24-10 19:46:17]: Attempting 4th retrial...
# ^C
# Traceback (most recent call last):
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/base_crawler.py", line 219, in start
#     self._handle_parse_url(url)
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/base_crawler.py", line 271, in _handle_parse_url
#     data = self.parse()
#            ^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/page_crawler/crawler.py", line 162, in parse
#     post = self.parse_post(i, post_div)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/page_crawler/crawler.py", line 185, in parse_post
#     owner_loc_anchors = profile_div.find_elements(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webelement.py", line 761, in find_elements
#     return self._execute(Command.FIND_CHILD_ELEMENTS,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webelement.py", line 710, in _execute
#     return self._parent.execute(command, params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 424, in execute
#     self.error_handler.check_response(response)
#   File "/home/ptdat/Desktop/venv/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py", line 247, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.InvalidSelectorException: Message: invalid selector
# from javascript error: {"status":32,"value":"Unable to locate an element with the xpath expression (((//div[@class='x9f619 x1n2onr6 x1ja2u2z xeuugli xs83m0k xjl7jj x1xmf6yo x1emribx x1e56ztr x1i64zmx x19h7ccj xu9j1y6 x7ep2pv']/div)[last()]/div/div[@class='x1yztbdb x1n2onr6 xh8yej3 x1ja2u2z'])[1]//h2/../../../../div//a because of the following error:\nSyntaxError: Failed to execute 'evaluate' on 'Document': The string '(((//div[@class='x9f619 x1n2onr6 x1ja2u2z xeuugli xs83m0k xjl7jj x1xmf6yo x1emribx x1e56ztr x1i64zmx x19h7ccj xu9j1y6 x7ep2pv']/div)[last()]/div/div[@class='x1yztbdb x1n2onr6 xh8yej3 x1ja2u2z'])[1]//h2/../../../../div//a' is not a valid XPath expression."}
#   (Session info: chrome=130.0.6723.69)
# Stacktrace:
# #0 0x5d24f88e80aa <unknown>
# #1 0x5d24f83ff1a0 <unknown>
# #2 0x5d24f8404ef3 <unknown>
# #3 0x5d24f8406ba5 <unknown>
# #4 0x5d24f8406c2c <unknown>
# #5 0x5d24f844b965 <unknown>
# #6 0x5d24f844bfa1 <unknown>
# #7 0x5d24f8440b53 <unknown>
# #8 0x5d24f846fdad <unknown>
# #9 0x5d24f84406d8 <unknown>
# #10 0x5d24f846ff4e <unknown>
# #11 0x5d24f848e866 <unknown>
# #12 0x5d24f846fb23 <unknown>
# #13 0x5d24f843e990 <unknown>
# #14 0x5d24f843f96e <unknown>
# #15 0x5d24f88b416b <unknown>
# #16 0x5d24f88b7f68 <unknown>
# #17 0x5d24f88a164c <unknown>
# #18 0x5d24f88b8ae7 <unknown>
# #19 0x5d24f88864af <unknown>
# #20 0x5d24f88d64f8 <unknown>
# #21 0x5d24f88d66c0 <unknown>
# #22 0x5d24f88e6f26 <unknown>
# #23 0x74ea5169ca94 <unknown>
# #24 0x74ea51729c3c <unknown>
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ptdat/Desktop/facebook-crawler-framework/main.py", line 105, in <module>
#     crawler.start()
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/page_crawler/crawler.py", line 359, in start
#     super().start(start_url=f"https://www.facebook.com/{self.page_id}")
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/base_crawler.py", line 245, in start
#     self.sleep()
#   File "/home/ptdat/Desktop/facebook-crawler-framework/crawlers/base_crawler.py", line 120, in sleep
#     time.sleep(sleep_second)
# KeyboardInterrupt
